# %%
import pandas as pd
df = pd.read_csv("originalDataset.csv")
df.head()
# Out:
#   Scorecard       Team 1     Team 2       Winner     Margin        Ground  \
# 0   ODI # 1    Australia    England    Australia  5 wickets     Melbourne
# 1   ODI # 2      England  Australia      England  6 wickets    Manchester
# 2   ODI # 3      England  Australia    Australia  5 wickets        Lord's
# 3   ODI # 4      England  Australia      England  2 wickets    Birmingham
# 4   ODI # 5  New Zealand   Pakistan  New Zealand    22 runs  Christchurch
#
#      Match Date
# 0   Jan 5, 1971
# 1  Aug 24, 1972
# 2  Aug 26, 1972
# 3  Aug 28, 1972
# 4  Feb 11, 1973

# %%
df.isnull().sum()
# Out:
# Scorecard       0
# Team 1          0
# Team 2          0
# Winner          0
# Margin        179
# Ground          0
# Match Date      0
# dtype: int64

# %%
df.dropna(axis=1)
# Out:
#        Scorecard        Team 1       Team 2        Winner        Ground  \
# 0        ODI # 1     Australia      England     Australia     Melbourne
# 1        ODI # 2       England    Australia       England    Manchester
# 2        ODI # 3       England    Australia     Australia        Lord's
# 3        ODI # 4       England    Australia       England    Birmingham
# 4        ODI # 5   New Zealand     Pakistan   New Zealand  Christchurch
# ...          ...           ...          ...           ...           ...
# 3927  ODI # 3928         India  New Zealand   New Zealand        Mumbai
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   East London
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan       Sharjah
# 3930  ODI # 3931         India  New Zealand         India          Pune
# 3931  ODI # 3932         India  New Zealand         India        Kanpur
#
#         Match Date
# 0      Jan 5, 1971
# 1     Aug 24, 1972
# 2     Aug 26, 1972
# 3     Aug 28, 1972
# ...

# %%
df.isnull().sum()
# Out:
# Scorecard       0
# Team 1          0
# Team 2          0
# Winner          0
# Margin        179
# Ground          0
# Match Date      0
# dtype: int64

# %%
df.dropna(subset=['Margin'])
# Out:
#        Scorecard        Team 1       Team 2        Winner     Margin  \
# 0        ODI # 1     Australia      England     Australia  5 wickets
# 1        ODI # 2       England    Australia       England  6 wickets
# 2        ODI # 3       England    Australia     Australia  5 wickets
# 3        ODI # 4       England    Australia       England  2 wickets
# 4        ODI # 5   New Zealand     Pakistan   New Zealand    22 runs
# ...          ...           ...          ...           ...        ...
# 3927  ODI # 3928         India  New Zealand   New Zealand  6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   200 runs
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan  9 wickets
# 3930  ODI # 3931         India  New Zealand         India  6 wickets
# 3931  ODI # 3932         India  New Zealand         India     6 runs
#
#             Ground    Match Date
# 0        Melbourne   Jan 5, 1971
# 1       Manchester  Aug 24, 1972
# 2           Lord's  Aug 26, 1972
# ...

# %%
df.dropna(thresh=7)  #atleat 7 non-nan value
# Out:
#        Scorecard        Team 1       Team 2        Winner     Margin  \
# 0        ODI # 1     Australia      England     Australia  5 wickets
# 1        ODI # 2       England    Australia       England  6 wickets
# 2        ODI # 3       England    Australia     Australia  5 wickets
# 3        ODI # 4       England    Australia       England  2 wickets
# 4        ODI # 5   New Zealand     Pakistan   New Zealand    22 runs
# ...          ...           ...          ...           ...        ...
# 3927  ODI # 3928         India  New Zealand   New Zealand  6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   200 runs
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan  9 wickets
# 3930  ODI # 3931         India  New Zealand         India  6 wickets
# 3931  ODI # 3932         India  New Zealand         India     6 runs
#
#             Ground    Match Date
# 0        Melbourne   Jan 5, 1971
# 1       Manchester  Aug 24, 1972
# 2           Lord's  Aug 26, 1972
# ...
